# %%
# !pip install langchain-text-splitter
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain-text-splitter (from versions: none)
# ERROR: No matching distribution found for langchain-text-splitter

# %%
import sys
# !{sys.executable} -m pip install langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter,Language
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
text = """
class Student:
    def __init__(self,name,age,grade):
      self,name = name
      self.age = age
      self.grade = grade #grade is float (like 8.5 or 9.2)
    def get_details(self):
      return self.name"

    def is_passing(self):
      return self.grade >= 6.0

  #Example usage
  student1 = Student("diksha",20,8.2)
  print(student1.get_details())

  if student1.is_passing():
    print("The student is passing.")
  else:
    print("The STudent is not passing.")
  """

# %%
#Initialize the splitter
Splitter = RecursiveCharacterTextSplitter.from_language(
    language = Language.PYTHON,
    chunk_size = 200,
    chunk_overlap = 20,

)

# %%
#Perform the split
chunks = Splitter.split_text(text)

# %%
print(len(chunks))
print(chunks[1])
# Out:
# 4
# return self.name"

# %%
print(chunks)
# Out:
# ['class Student:\n    def __init__(self,name,age,grade):\n      self,name = name\n      self.age = age\n      self.grade = grade #grade is float (like 8.5 or 9.2)\n    def get_details(self):', 'return self.name"', 'def is_passing(self):\n      return self.grade >= 6.0\n\n  #Example usage\n  student1 = Student("diksha",20,8.2)\n  print(student1.get_details())', 'if student1.is_passing():\n    print("The student is passing.")\n  else:\n    print("The STudent is not passing.")']

# %%
#Text-based splitting focuses on size, while document-based splitting focuses on meaning and structure
